# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy
# %matplotlib inline
# %load_ext sql

# %%
pdsi=pd.read_csv('pdsi2.csv').drop(columns=['Unnamed: 0'])
pdsi
# Out:
#      year    annual drought       marked
# 0    1908 -0.190833      no  no big fire
# 1    1909  0.208889      no  no big fire
# 2    1910 -1.680556      no  no big fire
# 3    1911  1.000278      no  no big fire
# 4    1912  0.166667      no  no big fire
# ..    ...       ...     ...          ...
# 110  2018 -1.678333      no  no big fire
# 111  2019  1.180556      no  no big fire
# 112  2020 -2.439444     yes  no big fire
# 113  2021 -4.349167     yes       2021/8
# 114  2022 -1.899444      no  no big fire
#
# [115 rows x 4 columns]
